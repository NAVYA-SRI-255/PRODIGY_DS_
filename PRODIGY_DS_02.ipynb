# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Product Sales.csv')
print(data.shape)
data.head(10)
# Out:
# (15000, 8)
#    week  sales_method                           customer_id  nb_sold  revenue  \
# 0     2         Email  2e72d641-95ac-497b-bbf8-4861764a7097       10      NaN
# 1     6  Email + Call  3998a98d-70f5-44f7-942e-789bb8ad2fe7       15   225.47
# 2     5          Call  d1de9884-8059-4065-b10f-86eef57e4a44       11    52.55
# 3     4         Email  78aa75a4-ffeb-4817-b1d0-2f030783c5d7       11      NaN
# 4     3         Email  10e6d446-10a5-42e5-8210-1b5438f70922        9    90.49
# 5     6          Call  6489e678-40f2-4fed-a48e-d0dff9c09205       13    65.01
# 6     4         Email  eb6bd5f1-f115-4e4b-80a6-5e67fcfbfb94       11   113.38
# 7     1         Email  047df079-071b-4380-9012-2bfe9bce45d5       10    99.94
# 8     5         Email  771586bd-7b64-40be-87df-afe884d2af9e       11   108.34
# 9     5          Call  56491dae-bbe7-49f0-a651-b823a01103d8       11    53.82
#
#    years_as_customer  nb_site_visits          state
# 0                  0              24        Arizona
# 1                  1              28         Kansas
# 2                  6              26      Wisconsin
# 3                  3              25        Indiana
# 4                  0              28       Illinois
# 5                 10              24    Mississippi
# 6                  9              28        Georgia
# 7                  1              22       Oklahoma
# 8                 10              31  Massachusetts
# 9                  7              23       Missouri

# %%
data['sales_method'] = data['sales_method'].str.lower()
data['sales_method'].replace({'em + call':'email + call'},inplace=True)
data['sales_method'].value_counts()
# Out:
# sales_method
# email           7466
# call            4962
# email + call    2572
# Name: count, dtype: int64

# %%
data[['week', 'nb_sold', 'sales_method']] = data[['week', 'nb_sold', 'sales_method']].astype('category')

# %%
# Drop duplicates
print(data.shape)
data.drop_duplicates(inplace= True)
data.shape
# Out:
# (15000, 8)
# (15000, 8)

# %%
data.isna().sum().sort_values()
# Out:
# week                    0
# sales_method            0
# customer_id             0
# nb_sold                 0
# years_as_customer       0
# nb_site_visits          0
# state                   0
# revenue              1074
# dtype: int64

# %%
data_bef =data.copy()
# Handling Outliers
def handle_outlier(df,col):
    Q3 = df[col].quantile(0.75)
    Q1 = df[col].quantile(0.25)
    IQR = Q3 - Q1
    upper = Q3 + (1.5 * IQR)
    lower = Q1 - (1.5 * IQR)
    df[col] = np.where(df[col] < lower, lower, df[col])
    df[col] = np.where(df[col] > upper, upper, df[col])

data_num = data.select_dtypes(include = ["float64", "int64"])

for column in data_num.columns:
    handle_outlier(data, column)

# %%
sns.set(style="darkgrid")
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.boxplot(data_bef,ax=axes[0])
sns.boxplot(data,ax=axes[1])
axes[0].set_title("Before Handling Outliers")
axes[1].set_title("After Handling Outliers")
fig.suptitle("The Distribution of Numeric Variables")
axes[0].set_xlabel("Numeric Variables")
axes[1].set_xlabel("Numeric Variables")

plt.tight_layout()
plt.show()

# %%
data_num = data.select_dtypes(include = ["float64", "int64"])
for col in data_num.columns:
  fig, axes = plt.subplots(1, 2, figsize=(12, 6))
  sns.histplot(data_bef[col], kde=True, color='blue',ax=axes[0], bins=20)
  sns.histplot(data[col], kde=True, color='blue',ax=axes[1], bins=20)
  axes[0].set_title("Before Handling Outliers")
  axes[1].set_title("After Handling Outliers")
  fig.suptitle('The Distribution of '+col)
  plt.tight_layout()
  plt.show()

# %%
data[['years_as_customer', 'nb_site_visits']] = data[['years_as_customer', 'nb_site_visits']].astype('int64')

# %%
data.sample(n=10)
# Out:
#       week  sales_method                           customer_id nb_sold  \
# 453      1         email  31b1dada-b80e-47fb-abe8-fcbeb75ff8dd       9
# 6104     6         email  fa4e115d-d937-4d97-826b-dc2542d38079      13
# 2750     1         email  ebfd6220-3a21-43ac-860d-2474b6980095       9
# 6000     5          call  9eb41d58-f3d3-4159-8774-5c845e79e30f      11
# 3580     1         email  88bfcdac-85ea-43d5-9bc1-185df161f640      10
# 10908    6  email + call  e87a3d5c-15e2-48be-9443-0fbb0ee9ee13      15
# 1583     2         email  16686bc1-e92e-458b-8182-ae7f85fde6bc      10
# 8377     5          call  67bc0c8a-ff0b-4f4d-aeab-50a0e3a58f3c      10
# 7106     2          call  e0752e90-de20-4f7f-af67-e3969c444063       9
# 10514    1         email  73b4e8d5-fe2c-45d0-8e29-dcdb11f74728       9
#
#        revenue  years_as_customer  nb_site_visits         state
# 453     88.720                  3              26      Michigan
# 6104   125.300                  3              24       Florida
# 2750    87.680                  5              28    California
# 6000    53.400                  1              32    California
# 3580   101.500                  2              26    California
# 10908  190.615                  3              28          Utah
# 1583    99.700                 16              24  Pennsylvania
# 8377    51.710                  1              23    New Mexico
# 7106    44.090                  8              17     Louisiana
# 10514   91.700                  6              23    California

# %%
# How many customers were there for each approach?
Customers = data.groupby('sales_method').size()
print(Customers)
Customers.plot(kind='pie', autopct='%1.0f%%')
plt.title('Distribution of Customers by Sales Method')
plt.show()
# Out:
# sales_method
# call            4962
# email           7466
# email + call    2572
# dtype: int64

# %%
# What does the spread of the revenue look like overall?
sns.kdeplot(data['revenue'], shade=True)
plt.xlabel('Revenue')
plt.ylabel('Density')
plt.title('Density of Revenue overall')
plt.show()
# Out:
# <ipython-input-15-f60d1d8d210e>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['revenue'], shade=True)

# %%
# What does the spread of the revenue look like for each method?
Mean_revenue = data.groupby('sales_method')['revenue'].sum()
print(Mean_revenue)
cx = Mean_revenue.plot.bar()
cx.bar_label(cx.containers[0], label_type='edge')
plt.title('Revenue Spread for Each Sales Method')
plt.show()
# Out:
# sales_method
# call            242968.065
# email           718012.340
# email + call    441038.225
# Name: revenue, dtype: float64

# %%
# Was there any difference in revenue over time for each of the methods?
sns.barplot(
    data=data, x="sales_method", y="revenue", hue="week", palette="rocket")

plt.title('The revenue of all sales methods increased each week')
# Out:
# Text(0.5, 1.0, 'The revenue of all sales methods increased each week')

# %%
 #the mean and medians of the methods' revenue per week
data.groupby(['week', 'sales_method'])['revenue'].agg(['mean', 'median']).unstack().style.background_gradient()
# Out:
# <style type="text/css">
# #T_16478_row0_col0, #T_16478_row0_col1, #T_16478_row0_col2, #T_16478_row0_col3, #T_16478_row0_col4, #T_16478_row0_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_16478_row1_col0 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_16478_row1_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_16478_row1_col2 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_16478_row1_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_16478_row1_col4 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_16478_row1_col5 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_16478_row2_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_16478_row2_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_16478_row2_col2 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_16478_row2_col3 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_16478_row2_col4 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_16478_row2_col5 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_16478_row3_col0 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_16478_row3_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_16478_row3_col2 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_16478_row3_col3 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_16478_row3_col4 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_16478_row3_col5 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_16478_row4_col0 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_16478_row4_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_16478_row4_col2 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_16478_row4_col3 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_16478_row4_col4 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_16478_row4_col5 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_16478_row5_col0, #T_16478_row5_col1, #T_16478_row5_col2, #T_16478_row5_col3, #T_16478_row5_col4, #T_16478_row5_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_16478" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16478_level0_col0" class="col_heading level0 col0" colspan="3">mean</th>
#       <th id="T_16478_level0_col3" class="col_heading level0 col3" colspan="3">median</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >sales_method</th>
#       <th id="T_16478_level1_col0" class="col_heading level1 col0" >call</th>
#       <th id="T_16478_level1_col1" class="col_heading level1 col1" >email</th>
#       <th id="T_16478_level1_col2" class="col_heading level1 col2" >email + call</th>
#       <th id="T_16478_level1_col3" class="col_heading level1 col3" >call</th>
#       <th id="T_16478_level1_col4" class="col_heading level1 col4" >email</th>
#       <th id="T_16478_level1_col5" class="col_heading level1 col5" >email + call</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >week</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16478_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_16478_row0_col0" class="data row0 col0" >35.414208</td>
#       <td id="T_16478_row0_col1" class="data row0 col1" >86.568597</td>
#       <td id="T_16478_row0_col2" class="data row0 col2" >123.790068</td>
#       <td id="T_16478_row0_col3" class="data row0 col3" >35.200000</td>
#       <td id="T_16478_row0_col4" class="data row0 col4" >86.500000</td>
#       <td id="T_16478_row0_col5" class="data row0 col5" >128.145000</td>
#     </tr>
#     <tr>
#       <th id="T_16478_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_16478_row1_col0" class="data row1 col0" >44.792484</td>
#       <td id="T_16478_row1_col1" class="data row1 col1" >99.553755</td>
#       <td id="T_16478_row1_col2" class="data row1 col2" >146.530100</td>
#       <td id="T_16478_row1_col3" class="data row1 col3" >43.500000</td>
#       <td id="T_16478_row1_col4" class="data row1 col4" >99.210000</td>
#       <td id="T_16478_row1_col5" class="data row1 col5" >153.735000</td>
#     </tr>
#     <tr>
#       <th id="T_16478_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_16478_row2_col0" class="data row2 col0" >42.904080</td>
#       <td id="T_16478_row2_col1" class="data row2 col1" >91.861739</td>
#       <td id="T_16478_row2_col2" class="data row2 col2" >144.078022</td>
#       <td id="T_16478_row2_col3" class="data row2 col3" >41.510000</td>
#       <td id="T_16478_row2_col4" class="data row2 col4" >91.725000</td>
#       <td id="T_16478_row2_col5" class="data row2 col5" >149.730000</td>
#     </tr>
#     <tr>
#       <th id="T_16478_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_16478_row3_col0" class="data row3 col0" >53.078428</td>
#       <td id="T_16478_row3_col1" class="data row3 col1" >107.566484</td>
#       <td id="T_16478_row3_col2" class="data row3 col2" >178.603576</td>
#       <td id="T_16478_row3_col3" class="data row3 col3" >51.330000</td>
#       <td id="T_16478_row3_col4" class="data row3 col4" >107.880000</td>
#       <td id="T_16478_row3_col5" class="data row3 col5" >180.570000</td>
#     </tr>
#     <tr>
#       <th id="T_16478_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_16478_row4_col0" class="data row4 col0" >54.669052</td>
#       <td id="T_16478_row4_col1" class="data row4 col1" >107.467941</td>
#       <td id="T_16478_row4_col2" class="data row4 col2" >180.622554</td>
#       <td id="T_16478_row4_col3" class="data row4 col3" >53.025000</td>
#       <td id="T_16478_row4_col4" class="data row4 col4" >107.860000</td>
#       <td id="T_16478_row4_col5" class="data row4 col5" >186.830000</td>
#     </tr>
#     <tr>
#       <th id="T_16478_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_16478_row5_col0" class="data row5 col0" >69.081150</td>
#       <td id="T_16478_row5_col1" class="data row5 col1" >128.229492</td>
#       <td id="T_16478_row5_col2" class="data row5 col2" >190.615000</td>
#       <td id="T_16478_row5_col3" class="data row5 col3" >66.035000</td>
#       <td id="T_16478_row5_col4" class="data row5 col4" >130.270000</td>
#       <td id="T_16478_row5_col5" class="data row5 col5" >190.615000</td>
#     </tr>
#   </tbody>
# </table>
